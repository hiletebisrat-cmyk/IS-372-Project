# %%
# google mount if necessary
from google.colab import drive
drive.mount('/content/drive')
dataset_path = '...'
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Data Understanding

# %%
# import necessary packages here
import pandas as pd
import numpy as np

# %%
# Importing Necessary Packages
dataset = pd.read_csv("FinalProject.csv")
dataset.head()
# Out:
#     Income  Limit  Rating  Cards   Age  Education  Own  Student  Married  \
# 0   14.891   3606   283.0      2  34.0         11    0      0.0        1
# 1  106.025   6645   483.0      3  82.0         15    1      1.0        1
# 2  104.593   7075   514.0      4  71.0         11    0      0.0        0
# 3  148.924   9504   681.0      3  36.0         11    1      0.0        0
# 4   55.882   4897   357.0      2  68.0         16    0      0.0        1
#
#   Region  Balance Balance_level
# 0  South      333           Low
# 1   West      903          High
# 2   West      580          High
# 3   West      964          High
# 4  South      331           Low

# %%
# Basic Data Information
rows, columns = dataset.shape
print(f"The shape of the dataset is: {rows}, rows and {columns}, columns")
# Out:
# The shape of the dataset is: 402, rows and 12, columns

# %%
# Display the first few rows
print(dataset.head())
# Out:
#     Income  Limit  Rating  Cards   Age  Education  Own  Student  Married  \
# 0   14.891   3606   283.0      2  34.0         11    0      0.0        1
# 1  106.025   6645   483.0      3  82.0         15    1      1.0        1
# 2  104.593   7075   514.0      4  71.0         11    0      0.0        0
# 3  148.924   9504   681.0      3  36.0         11    1      0.0        0
# 4   55.882   4897   357.0      2  68.0         16    0      0.0        1
#
#   Region  Balance Balance_level
# 0  South      333           Low
# 1   West      903          High
# 2   West      580          High
# 3   West      964          High
# 4  South      331           Low

# %%
# Get dataset dimensions (rows, columns)
dataset.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 402 entries, 0 to 401
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Income         400 non-null    float64
#  1   Limit          402 non-null    int64
#  2   Rating         400 non-null    float64
#  3   Cards          402 non-null    int64
#  4   Age            400 non-null    float64
#  5   Education      402 non-null    int64
#  6   Own            402 non-null    int64
#  7   Student        398 non-null    float64
#  8   Married        402 non-null    int64
#  9   Region         402 non-null    str
#  10  Balance        402 non-null    int64
#  11  Balance_level  402 non-null    str
# dtypes: float64(4), int64(6), str(2)
# memory usage: 37.8 KB

# %%
# Identifying Variable Types
quan_data = ['Income', 'Limit', 'Rating', 'Cards', 'Age', 'Education', 'Balance']
cate_data = ['Own', 'Student', 'Married', 'Balance_level']

# %% [markdown]
# # Data Cleaning and Preprocessing

# %% [markdown]
# ## Missing value

# %%
# Check the missing values.

# %%
# Handling missing values:
data_missing = dataset.copy()

# use trimmed mean to replace the missing value of income.

# use media to replace the missing value of rating.

# use round up of mean to replace the missing value of age.

# use mode to replace missing value of all categorical data.

# %% [markdown]
# ## Duplication

# %%
# Detecting and removing duplicates.
data_duplication = data_missing.copy()

# %% [markdown]
# ## Outliers

# %%
data_outliers = data_duplication.copy()

# %%
# Checking for outliers using box plots.

# %%
# If there are duplicates, remove the outliers.


# Compute the First and Third Quartiles

# Calculate the Interquartile Range (IQR)

# Determine Outlier Boundaries


# Remove Outliers
df_clean = ...

# %% [markdown]
# # Data Exploration

# %% [markdown]
# ## Quantitative Data

# %%
# function of quantitative exploration
def quan_exploration(dataset, variable):
  # mean

  #trimmed_mean

  # median

  # std

  # range

  # IQR

  # plot the box

  # create a new figure and axes for the density histogram

  # plot the density histogram

# %%
# print the results of all quan_data

# %% [markdown]
# ## Categorical data

# %%
# function of categorical exploration
def cal_exploration(dataset, variable):
  # find the mode of variable


  # find the propability of category


  # barchart

# %%
# print the results of all cate_data

# %% [markdown]
# # Relationship Exporation

# %% [markdown]
# ## Quan vs. 'Balance'

# %%
# fucntion of corr_exploration

# %%
'''
Only print the result of Quantitative variable
whose absolute value of the correlation coefficient vs. 'Balance'
is greater than 0.4.
'''

# %% [markdown]
# ## Cate vs. 'Balance_Level'

# %%
# fucntion of cate_relationship

# %%
# fucntion of chi-square test

# %%
'''
Only print the result of Categorical variable vs. 'Balance_Level'
whose p-value is less than 0.05.
'''

# %% [markdown]
# ## Cate vs. Quan

# %%
# fucntion of categorical dava vs. quantitative data

# %%
# fucntion of ANOVA test

# %%
'''
Only print the result of quantitative variable vs. 'Balance_Level'
whose p-value is less than 0.05.
'''

# %% [markdown]
# # Predictive Modeling

# %% [markdown]
# ## Multiple Regression

# %%
# Using the variables you found from correlation coefficient test as the predictors.




# Fitting a multiple linear regression model.
# Out:
# Rating    0.856498
# Limit     0.854275
# Income    0.418438
# Name: Balance, dtype: float64

# %% [markdown]
# ## stepwise_selection

# %% [markdown]
# Using stepwise selection to identify the most significant variables influencing “Balance”.

# %%
# Initialize lists and variables
predictor_list = []
Model_Adj_R_squared = 0
Best_Adj_R_squared = 0
best_regression_model = None  # Variable to store the best model
best_predictors = []  # List to store best predictors

# Iterate through the index and values


# After the loop, print the equation of the best model

# %% [markdown]
# # Classification

# %%
# Using the variables you found from chi-square and ANOVA test as the predictors.
X_tree =
# Using “Balance_level” as the target outcome.
y_tree =

# split the data into training and testing sets.

# %%
# Train five models based on the following requirement.
knn_5 =
knn_10 =

balance_tree =
balance_tree_minsamplesplit =
balance_tree_minsampleleaf =

# %%
# Use each model to predict the y_test subsets.
y_pred_knn_5 =
y_pred_knn_10 =
y_pred_tree =
y_pred_tree_minsamplesplit =
y_pred_tree_minsampleleaf =

# %%
# Generate confusion matrices for each model.

# %%
# plot balance_tree to find the number of leaf nodes.

# %%
# plot y_pred_tree_minsamplesplit to find the number of leaf nodes.

# %%
# plot y_pred_tree_minsampleleaf to find the number of leaf nodes.

# %% [markdown]
# # prediction

# %%
# load the FinalPrediction.csv

# %%
# Use the multiple linear regression model to predict "Balance".

# %%
# Use the best decision tree model to predict "Balance_level"
